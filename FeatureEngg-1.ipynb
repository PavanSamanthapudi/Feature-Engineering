# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Running cells with 'fe-env (3.12.12) (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/Practice UDS 2.0/Feature Engineering/fe-env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
